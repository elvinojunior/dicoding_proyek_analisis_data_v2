# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public
# - **Nama:** Elvino Junior
# - **Email:** elvinojunior75@gmail.com
# - **ID Dicoding:** elvinojr75

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
aotiz_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aotiz_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changping_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Changping_20130301-20170228.csv")
changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
dingling_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Dingling_20130301-20170228.csv")
dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
dongsi_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Dongsi_20130301-20170228.csv")
dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
guanyu_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Guanyuan_20130301-20170228.csv")
guanyu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
gucheng_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Gucheng_20130301-20170228.csv")
gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
huairo_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Huairou_20130301-20170228.csv")
huairo_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
nongzhang_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Nongzhanguan_20130301-20170228.csv")
nongzhang_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
shunyi_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Shunyi_20130301-20170228.csv")
shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
tiantan_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Tiantan_20130301-20170228.csv")
tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
wanliu_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Wanliu_20130301-20170228.csv")
wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
wansho_df = pd.read_csv("https://raw.githubusercontent.com/elvinojunior/dicoding_proyek_analisis_data_v2/refs/heads/main/data/PRSA_Data_Wanshouxigong_20130301-20170228.csv")
wansho_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# **insight** :
#
# pada masing-masing table memiliki kolom yang berisi :
# *   year, month, day, hour : waktu pada saat data dihasilkan
# *   PM2.5: Konsentrasi partikel debu halus berukuran 2.5 mikrometer
# *   PM10: Konsentrasi partikel debu berukuran 10 mikrometer
# *   SO2, NO2, CO, 03 : Senyawa/zat yang terkandung dalam udara
# *   TEMP: Suhu
# *   PRES: Tekanan udara
# *   DEWP: Titik embun
# *   RAIN: Curah hujan
# *   wd: Arah angin
# *   WSPM: Kecepatan angin
# station

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai apakah masing masing data terdapat nilai duplikat :

# %%
print("Jumlah duplikasi pada table aotiz \t: ", aotiz_df.duplicated().sum())
print("Jumlah duplikasi pada table changping \t: ", changping_df.duplicated().sum())
print("Jumlah duplikasi pada table dingling \t: ", dingling_df.duplicated().sum())
print("Jumlah duplikasi pada table dongsi \t: ", dongsi_df.duplicated().sum())
print("Jumlah duplikasi pada table guanyu \t: ", guanyu_df.duplicated().sum())
print("Jumlah duplikasi pada table gucheng \t: ", gucheng_df.duplicated().sum())
print("Jumlah duplikasi pada table huairo \t: ", huairo_df.duplicated().sum())
print("Jumlah duplikasi pada table nongzhang \t: ", nongzhang_df.duplicated().sum())
print("Jumlah duplikasi pada table shunyi \t: ", shunyi_df.duplicated().sum())
print("Jumlah duplikasi pada table tiantan \t: ", tiantan_df.duplicated().sum())
print("Jumlah duplikasi pada table wanliu \t: ", wanliu_df.duplicated().sum())
print("Jumlah duplikasi pada table wansho \t: ", wansho_df.duplicated().sum())
# Out:
# Jumlah duplikasi pada table aotiz 	:  0
# Jumlah duplikasi pada table changping 	:  0
# Jumlah duplikasi pada table dingling 	:  0
# Jumlah duplikasi pada table dongsi 	:  0
# Jumlah duplikasi pada table guanyu 	:  0
# Jumlah duplikasi pada table gucheng 	:  0
# Jumlah duplikasi pada table huairo 	:  0
# Jumlah duplikasi pada table nongzhang 	:  0
# Jumlah duplikasi pada table shunyi 	:  0
# Jumlah duplikasi pada table tiantan 	:  0
# Jumlah duplikasi pada table wanliu 	:  0
# Jumlah duplikasi pada table wansho 	:  0

# %% [markdown]
# **insight** :
#
# Dapat dilihat pada masing-masing data tidak memiliki nilai duplikat

# %% [markdown]
# *   Menilai Data Aotiz

# %%
aotiz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
aotiz_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
aotiz_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %% [markdown]
# *   Menilai Data changping

# %%
changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %% [markdown]
# *   Menilai Data dingling

# %%
dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
dingling_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %% [markdown]
# *   Menilai Data dongsi

# %%
dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %% [markdown]
# *   Menilai Data guanyu

# %%
guanyu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
guanyu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
guanyu_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %% [markdown]
# *   Menilai Data gucheng

# %%
gucheng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
gucheng_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# ...

# %% [markdown]
# *   Menilai Data huairo

# %%
huairo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
huairo_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
huairo_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %% [markdown]
# *   Menilai Data nongzhang

# %%
nongzhang_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
nongzhang_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
nongzhang_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# ...

# %% [markdown]
# *   Menilai Data shunyi

# %%
shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
shunyi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %% [markdown]
# *   Menilai Data tiantan

# %%
tiantan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
tiantan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# ...

# %% [markdown]
# *   Menilai Data wanliu

# %%
wanliu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
wanliu_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# ...

# %% [markdown]
# *   Menilai Data wansho

# %%
wansho_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
wansho_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
wansho_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %% [markdown]
# **Insight** :
#
#
# *   Dapat dilihat pada masing-masing data/table dengan kolom PM2.5 sampai WSPM banyak yang memiliki *missing values* atau nilai yang kosong
# *   Pada kolom year, month, day, hour masih bertipe data int64 dan terpisah
# *   tidak ada *inaccurate values* pada saat menggunakan fungsi ".describe()"

# %% [markdown]
# ### Cleaning Data

# %%
linear_cols = ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3", "TEMP", "PRES", "DEWP"]

aotiz_df[linear_cols] = aotiz_df[linear_cols].interpolate(method='linear', limit_direction='both')
changping_df[linear_cols] = changping_df[linear_cols].interpolate(method='linear', limit_direction='both')
dingling_df[linear_cols] = dingling_df[linear_cols].interpolate(method='linear', limit_direction='both')
dongsi_df[linear_cols] = dongsi_df[linear_cols].interpolate(method='linear', limit_direction='both')
guanyu_df[linear_cols] = guanyu_df[linear_cols].interpolate(method='linear', limit_direction='both')
gucheng_df[linear_cols] = gucheng_df[linear_cols].interpolate(method='linear', limit_direction='both')
huairo_df[linear_cols] = huairo_df[linear_cols].interpolate(method='linear', limit_direction='both')
nongzhang_df[linear_cols] = nongzhang_df[linear_cols].interpolate(method='linear', limit_direction='both')
shunyi_df[linear_cols] = shunyi_df[linear_cols].interpolate(method='linear', limit_direction='both')
tiantan_df[linear_cols] = tiantan_df[linear_cols].interpolate(method='linear', limit_direction='both')
wanliu_df[linear_cols] = wanliu_df[linear_cols].interpolate(method='linear', limit_direction='both')
wansho_df[linear_cols] = wansho_df[linear_cols].interpolate(method='linear', limit_direction='both')

# %% [markdown]
# **Insight** :
#
#
# *   Disini saya menggunakan teknik interpolasi linear untuk pengisian pada kolom ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3", "TEMP", "PRES", "DEWP"] karna polutan udara dan variabel meteorologi umumnya memiliki tren linier dalam jangka pendek
# *   Metode ini mempertahankan pola alami perubahan polutan dan cuaca tanpa memperkenalkan bias besar

# %%
def fill_missing_values(df):
    """Fungsi untuk mengisi nilai yang hilang sesuai kriteria."""
    if "wd" in df.columns:
        df.loc[:, "wd"] = df["wd"].fillna(df["wd"].mode()[0])

    if "WSPM" in df.columns:
        df.loc[:, "WSPM"] = df["WSPM"].fillna(df["WSPM"].median())

    if "RAIN" in df.columns:
        df.loc[:, "RAIN"] = df["RAIN"].fillna(0)

    return df

# %%
dataframes = [aotiz_df, changping_df, dingling_df, dongsi_df, guanyu_df,
              gucheng_df, huairo_df, nongzhang_df, shunyi_df, tiantan_df,
              wanliu_df, wansho_df]

dataframes = [fill_missing_values(df) for df in dataframes]

# %% [markdown]
# **Insight** :
#
# Disini saya membuat fungsi untuk melakukan teknik pengisian missing value menggunakan metode imputation yaitu :
# * pada kolom "wd" mengambil nilai modus (nilai paling sering muncul)
# * pada kolom "WSPM" mengambil nilai median (nilai tengah)
#
# * pada kolom "RAIN" mengisi dengan nilai 0 (anggap tidak hujan)

# %%
def to_datetime(df) :
  df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])
  df.drop(columns=['year', 'month', 'day', 'hour'], inplace=True)
  return df

dataframes = [to_datetime(df) for df in dataframes]

# %% [markdown]
# **Insight** :
#
# *   Disini saya membuat kolom datetime dengan tipe data datetime untuk memudahkan saya saat proses *Exploratory Data Analyst*
# *   serta saya menghapus kolom ['year', 'month', 'day', 'hour'] karna sudah saya gabungkan di kolom datetime untuk memudahkan

# %%
def show_info(df):
  df.info()
  print("\n")

dataframes=[show_info(df) for df in dataframes]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        35064 non-null  int64
#  1   PM2.5     35064 non-null  float64
#  2   PM10      35064 non-null  float64
#  3   SO2       35064 non-null  float64
#  4   NO2       35064 non-null  float64
#  5   CO        35064 non-null  float64
#  6   O3        35064 non-null  float64
#  7   TEMP      35064 non-null  float64
#  8   PRES      35064 non-null  float64
#  9   DEWP      35064 non-null  float64
#  10  RAIN      35064 non-null  float64
#  11  wd        35064 non-null  object
#  12  WSPM      35064 non-null  float64
#  13  station   35064 non-null  object
#  14  datetime  35064 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 4.0+ MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# ...

# %% [markdown]
# **Insight** :
#
# Terlihat pada setiap data frame yang kita miliki bahwa nilai nya sudah bersih dan tidak ada missing value lagi

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
df_list = [aotiz_df, changping_df, dingling_df, dongsi_df, guanyu_df, gucheng_df,
           huairo_df, nongzhang_df, shunyi_df, tiantan_df, wanliu_df, wansho_df]

combined_df = pd.concat(df_list, ignore_index=True)

print(combined_df.info())
print("="*50)
print(combined_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   No        420768 non-null  int64
#  1   PM2.5     420768 non-null  float64
#  2   PM10      420768 non-null  float64
#  3   SO2       420768 non-null  float64
#  4   NO2       420768 non-null  float64
#  5   CO        420768 non-null  float64
#  6   O3        420768 non-null  float64
#  7   TEMP      420768 non-null  float64
#  8   PRES      420768 non-null  float64
#  9   DEWP      420768 non-null  float64
#  10  RAIN      420768 non-null  float64
#  11  wd        420768 non-null  object
#  12  WSPM      420768 non-null  float64
#  13  station   420768 non-null  object
#  14  datetime  420768 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 48.2+ MB
# None
# ...

# %% [markdown]
# **Insight** : Disini saya melakukan penggabungan dataset agar memudahkan saya dalam mengeksplorasi lebih lanjut

# %%
combined_df.groupby(combined_df['datetime'].dt.year)['RAIN'].mean()
# Out:
# datetime
# 2013    0.066097
# 2014    0.049793
# 2015    0.075997
# 2016    0.075975
# 2017    0.002813
# Name: RAIN, dtype: float64

# %% [markdown]
# **Insight** : Dapat terlihat rata-rata curah hujan tertinggi periode 5 tahun (2013-2017) dimilki oleh tahun 2015 pada posisi pertama

# %%
# Filter data untuk tahun 2016
df_2015 = combined_df[combined_df["datetime"].dt.year == 2015]

# Kelompokkan berdasarkan bulan dan jumlahkan nilai CO
co_summary = df_2015.groupby(df_2015["datetime"].dt.month)["CO"].agg(
    jumlah_CO="sum",
    rata_CO="mean",
).reset_index()

co_summary
# Out:
#     datetime     jumlah_CO      rata_CO
# 0          1  1.697902e+07  1901.771580
# 1          2  1.173145e+07  1454.792907
# 2          3  1.058960e+07  1186.111111
# 3          4  6.528550e+06   755.619213
# 4          5  6.439800e+06   721.303763
# 5          6  9.086800e+06  1051.712963
# 6          7  7.269550e+06   814.241711
# 7          8  6.963900e+06   780.006720
# 8          9  6.996900e+06   809.826389
# 9         10  8.434200e+06   944.690860
# 10        11  1.672528e+07  1935.795718
# 11        12  2.490762e+07  2789.832549

# %% [markdown]
# **Insight** : Disini saya ingin melihat jumlah carbon monoksida yang dihasilkan dari industri, kendaraan, dan lain lainnya perbulan pada tahun 2015 (karna memiliki curah hujan tertinggi) produksi carbon monoksida tertinggi ada pada awal dan akhir tahun

# %%
combined_df.groupby("station")[["PM2.5", "PM10", "NO2"]].mean().sort_values(by=["PM2.5", "PM10", "NO2"], ascending=False)
# Out:
#                    PM2.5        PM10        NO2
# station
# Dongsi         86.144243  110.347617  53.953078
# Nongzhanguan   85.079472  109.384022  58.095053
# Wanshouxigong  85.067548  112.505795  55.495402
# Gucheng        84.074802  119.261567  55.822315
# Wanliu         83.467612  110.707858  65.668418
# Guanyuan       82.897522  109.372349  58.139298
# Aotizhongxin   82.540623  110.210033  59.074106
# Tiantan        82.033097  106.537076  53.258828
# Shunyi         79.437962   99.271936  44.094695
# Changping      70.986438   94.788575  44.206153
# Huairou        69.501747   92.422670  32.077275
# Dingling       66.845557   84.113713  27.303589

# %% [markdown]
# **Insight** : Disini saya menampilkan data terurut mulai dari tertinggi sampe terendah pada setiap stasiun penghasil polutan berdasarkan dataset periode tahun 2013-2017

# %%
combined_df.groupby(["station", combined_df["datetime"].dt.year])["TEMP"].max().unstack()
# Out:
# datetime       2013  2014  2015  2016  2017
# station
# Aotizhongxin   37.9  40.5  38.8  37.3  15.9
# Changping      37.9  41.4  39.2  38.1  15.6
# Dingling       37.9  41.4  39.2  38.1  15.6
# Dongsi         37.5  41.1  38.8  37.3  15.9
# Guanyuan       37.9  40.5  38.8  37.3  15.9
# Gucheng        37.7  41.6  39.3  37.2  15.5
# Huairou        36.9  40.3  39.0  36.5  15.8
# Nongzhanguan   37.5  41.1  38.8  37.3  15.9
# Shunyi         37.8  40.6  39.0  36.6  15.4
# Tiantan        37.5  41.1  38.8  37.3  15.9
# Wanliu         37.9  40.5  39.0  38.2  16.2
# Wanshouxigong  38.0  40.6  38.8  37.3  15.9

# %% [markdown]
# **Insight** : Saya masih penasaran dengan suhu terpanas pada masing masing stasiun tiap tahunnya. untuk memudahkan saya melihat saya menggunakan *pivot table*

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# Setelah Hasil Data wrangling dan Exploratory Data Analysis menimbulkan pertanyaan ke dalam diri saya yaitu :
#
# - Apakah hujan membantu mengurangi polusi udara secara signifikan?
# - Apakah ada stasiun tertentu yang selalu memiliki kualitas udara buruk?

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Menambahkan kategori apakah ada hujan atau tidak
combined_df["Rain Condition"] = combined_df["RAIN"].apply(lambda x: "No Rain" if x == 0 else "Rain")

# Membuat visualisasi menggunakan boxplot untuk setiap stasiun
custom_palette = {"No Rain": "orange", "Rain": "skyblue"}
plt.figure(figsize=(12, 6))
sns.boxplot(x="station", y="PM2.5", hue="Rain Condition", data=combined_df, showfliers=False, palette=custom_palette)

plt.xlabel("Stasiun")
plt.ylabel("Konsentrasi PM2.5 (µg/m³)")
plt.title("Perbandingan PM2.5 Saat Hujan dan Tidak Hujan di Setiap Stasiun")
plt.xticks(rotation=45)
plt.legend(title="Kondisi Hujan")
plt.show()

# %% [markdown]
# **Insight** :
#
# * Disini saya melakukan visualisasi menggunakan boxplot agar memudahkan saya melihat median, kuartil, dan rentang interkuartil (IQR). Ini membantu dalam memahami sebaran data dengan cepat serta lebih efisien terhadap dataset besar
# * Saya membandingkan antara pada saat hujan dengan tidak hujan berdasarkan rata-rata dari PM2.5(polusi partikel 2.5) bisa dilihat dengan adanya hujan (biru) dapat mengurangi polusi partikel 2.5

# %%
# Menambahkan kategori apakah ada hujan atau tidak
combined_df["Rain Condition"] = combined_df["RAIN"].apply(lambda x: "No Rain" if x == 0 else "Rain")

# Membuat visualisasi menggunakan boxplot untuk setiap stasiun
custom_palette = {"No Rain": "orange", "Rain": "skyblue"}
plt.figure(figsize=(12, 6))
sns.boxplot(x="station", y="PM10", hue="Rain Condition", data=combined_df, showfliers=False, palette=custom_palette)

plt.xlabel("Stasiun")
plt.ylabel("Konsentrasi PM10 (µg/m³)")
plt.title("Perbandingan PM10 Saat Hujan dan Tidak Hujan di Setiap Stasiun")
plt.xticks(rotation=45)
plt.legend(title="Kondisi Hujan")
plt.show()

# %% [markdown]
# **Insight** :
# * Selanjutnya saya membandingkan antara pada saat hujan dengan tidak hujan berdasarkan rata-rata dari PM10(polusi partikel 10) bisa dilihat dengan adanya hujan (biru) dapat mengurangi polusi partikel 10

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Menambahkan kolom tahun dari datetime
combined_df["year"] = combined_df["datetime"].dt.year

# Menghitung rata-rata PM2.5 dan PM10 per tahun untuk setiap stasiun
pm_yearly_avg = combined_df.groupby(["station", "year"])[["PM2.5", "PM10"]].mean().reset_index()

# Membuat visualisasi tren PM2.5 dan PM10 di setiap stasiun dari tahun ke tahun
fig, axes = plt.subplots(nrows=len(stations), figsize=(12, 5 * len(stations)))

for i, station in enumerate(stations):
    subset = pm_yearly_avg[pm_yearly_avg["station"] == station]

    ax = axes[i] if len(stations) > 1 else axes
    ax.plot(subset["year"], subset["PM2.5"], marker="o", linestyle="-", label="PM2.5", color="red")
    ax.plot(subset["year"], subset["PM10"], marker="s", linestyle="--", label="PM10", color="orange")

    ax.set_title(f"Tren Rata-rata Polusi Udara di {station} (PM2.5 & PM10)")
    ax.set_xlabel("Tahun")
    ax.set_ylabel("Konsentrasi (µg/m³)")
    ax.legend()
    ax.grid(True)

    # Menyesuaikan tampilan sumbu x hanya untuk tahun tertentu
    ax.set_xticks([2013, 2014, 2015, 2016, 2017])
    ax.set_xlim(2013, 2017)

    # Menyesuaikan batas sumbu y dari 0 hingga 150
    ax.set_ylim(0, 150)

plt.suptitle("Perkembangan Kualitas Udara di Setiap Stasiun dari Tahun ke Tahun", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %% [markdown]
# **Insight:**
# - Disini saya menggunakan line chart agar memudahkan saya membandingkan rata-rata pergerakan setiap tahun dari polusi udara yang dihasilkan setiap tahunnya
# - Berdasarkan visualisasi data pada tahun 2013-2017 terhadap stasiun yang menghasilkan polusi udara tertinggi dan secara rata-rata di pegang oleh Dongsi dan Gucheng

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
combined_df.to_csv("combined_df.csv", index=False)
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   No        420768 non-null  int64
#  1   PM2.5     420768 non-null  float64
#  2   PM10      420768 non-null  float64
#  3   SO2       420768 non-null  float64
#  4   NO2       420768 non-null  float64
#  5   CO        420768 non-null  float64
#  6   O3        420768 non-null  float64
#  7   TEMP      420768 non-null  float64
#  8   PRES      420768 non-null  float64
#  9   DEWP      420768 non-null  float64
#  10  RAIN      420768 non-null  float64
#  11  wd        420768 non-null  object
#  12  WSPM      420768 non-null  float64
#  13  station   420768 non-null  object
#  14  datetime  420768 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 48.2+ MB

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Setelah Hasil Visualization dan Explanatory Data Analysis dapat kita simpulkan yaitu :
#
# - hujan mampu membantu mengurangi polusi udara dari PM2.5(polusi udara yang dikeluarkan kendaraan, industri) dan PM10(polusi udara yang dikeluarkan dari pembakaran, limbah serta debu jalanan) yang dihasilkan setiap tahunnya oleh masing-masing stasiun selama periode 5tahun
#
# - Stasiun dengan kualitas udara buruk dan tidak ada peningkatan setiap tahunnya yaitu Dongsi dan Gucheng, serta polusi udara paling baik serta konsisten yaitu dingling
